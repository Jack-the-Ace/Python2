# %%
import matplotlib.pyplot as plt

# %%
xs=[1,2,3,4]
ys=[1100, 2000, 2900, 3800]

# %%
plt.plot(xs,ys)
plt.xlabel('quantity of apples')
plt.ylabel('price')
plt.show()

# %%
import pandas as pd
data = {
    '월': ['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'],
    '매출액(만원)': [4200, 3900, 4500, 4700, 5200, 5800, 6100, 6400, 5900, 5500, 5300, 5000]
}
df=pd.DataFrame(data)

# %%
print(df)
df
# Out:
#       월  매출액(만원)
# 0    1월     4200
# 1    2월     3900
# 2    3월     4500
# 3    4월     4700
# 4    5월     5200
# 5    6월     5800
# 6    7월     6100
# 7    8월     6400
# 8    9월     5900
# 9   10월     5500
# 10  11월     5300
# 11  12월     5000
#       월  매출액(만원)
# 0    1월     4200
# 1    2월     3900
# 2    3월     4500
# 3    4월     4700
# 4    5월     5200
# 5    6월     5800
# 6    7월     6100
# 7    8월     6400
# 8    9월     5900
# 9   10월     5500
# 10  11월     5300
# 11  12월     5000

# %%
import numpy as np
aa=np.array([10,20,30])
bb=np.array([4,5,6])
print(aa.shape)
print(bb.shape)
# Out:
# (3,)
# (3,)

# %%
aa=pd.Series([10,20,30])
print(aa)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
ee=pd.Series([100,200,300], dtype='object', index=['a','b','c'])
print(ee)
print(ee['c'])
ee.shape
# Out:
# a    100
# b    200
# c    300
# dtype: object
# 300
# (3,)

# %%
temp=pd.Series([-10,-5,-4,10,20,25])
print(temp)
# Out:
# 0   -10
# 1    -5
# 2    -4
# 3    10
# 4    20
# 5    25
# dtype: int64
